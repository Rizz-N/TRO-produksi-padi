# %%
import pandas as pd
df = pd.read_excel("Excel solver dataset.xlsx")
fc =
# Out:
#    Angka pada sel adalah biaya per ton dalam ribuan rupiah Unnamed: 1  \
# 0                                                 NaN             NaN
# 1                                    Sumber  \ tujuan           Medan
# 2                                             Lampung              10
# 3                                Kep. Bangka Belitung               8
# 4                                           Kep. Riau               6
# 5                                         DKI Jakarta              12
# 6                                          Jawa Barat              14
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                          Matriks variabel Keputusan             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# ...
